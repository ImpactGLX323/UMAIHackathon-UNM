# %%
# Import libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, accuracy_score, f1_score
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier, StackingClassifier

# %%
# Load the processed dataset
df = pd.read_csv('../data/preprocessed/with_diabetes_status/dataset_with_diabetes_status.csv')

# %%
# Data inspection: view first 10 rows and shape
print("First ten rows of the dataset:")
display(df.head(10))

print("\nDataset dimensions:")
print(f"Number of rows: {df.shape[0]}, Number of columns: {df.shape[1]}")
# Out:
# First ten rows of the dataset:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
# 5  Female  20.0             0              0           never  27.32
# 6  Female  44.0             0              0           never  19.31
# 7  Female  79.0             0              0         No Info  23.86
# 8    Male  42.0             0              0           never  33.64
# 9  Female  32.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level  diabetes                 diabetes_status
# 0          6.6                  140         0  stress induced type 2 diabetic
# 1          6.6                   80         0  stress induced type 2 diabetic
# 2          5.7                  158         0      stress induced prediabetic
# 3          5.0                  155         0                    non diabetic
# 4          4.8                  155         0                    non diabetic
# 5          6.6                   85         0  stress induced type 2 diabetic
# 6          6.5                  200         1                        diabetic
# 7          5.7                   85         0      stress induced prediabetic
# 8          4.8                  145         0                    non diabetic
# 9          5.0                  100         0                    non diabetic
# Dataset dimensions:
# Number of rows: 100000, Number of columns: 10

# %%
# Data inspection: data information
print("\nDataset information:")
df.info()
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
#  9   diabetes_status      100000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 7.6+ MB

# %%
# Data inspection: statistical summary
print("\nStatistical summary:")
display(df.describe())
# Out:
# Statistical summary:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# 50%         5.800000           140.000000       0.000000
# 75%         6.200000           159.000000       0.000000
# max         9.000000           300.000000       1.000000

# %%
# Data inspection: unique values and counts
for column in df.columns:
    print(f"Unique values in '{column}':")
    print(df[column].unique())
    print(f"\nUnique value counts in '{column}':")
    print(df[column].value_counts())
    print("\n")
# Out:
# Unique values in 'gender':
# ['Female' 'Male' 'Other']
#
# Unique value counts in 'gender':
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64
#
#
# Unique values in 'age':
# [80.   54.   28.   36.   76.   20.   44.   79.   42.   32.   53.   78.
#  67.   15.   37.   40.    5.   69.   72.    4.   30.   45.   43.   50.
#  41.   26.   34.   73.   77.   66.   29.   60.   38.    3.   57.   74.
#  19.   46.   21.   59.   27.   13.   56.    2.    7.   11.    6.   55.
#   9.   62.   47.   12.   68.   75.   22.   58.   18.   24.   17.   25.
#   0.08 33.   16.   61.   31.    8.   49.   39.   65.   14.   70.    0.56
#  48.   51.   71.    0.88 64.   63.   52.    0.16 10.   35.   23.    0.64
#   1.16  1.64  0.72  1.88  1.32  0.8   1.24  1.    1.8   0.48  1.56  1.08
#   0.24  1.4   0.4   0.32  1.72  1.48]
#
# Unique value counts in 'age':
# age
# 80.00    5621
# 51.00    1619
# 47.00    1574
# 48.00    1568
# 53.00    1542
#          ...
# 0.48       83
# 1.00       83
# 0.40       66
# 0.16       59
# 0.08       36
# Name: count, Length: 102, dtype: int64
#
#
# Unique values in 'hypertension':
# [0 1]
#
# Unique value counts in 'hypertension':
# hypertension
# 0    92515
# 1     7485
# Name: count, dtype: int64
#
#
# Unique values in 'heart_disease':
# [1 0]
#
# Unique value counts in 'heart_disease':
# heart_disease
# 0    96058
# 1     3942
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history':
# ['never' 'No Info' 'current' 'former' 'ever' 'not current']
#
# Unique value counts in 'smoking_history':
# smoking_history
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64
#
#
# Unique values in 'bmi':
# [25.19 27.32 23.45 ... 59.42 44.39 60.52]
#
# Unique value counts in 'bmi':
# bmi
# 27.32    25495
# 23.00      103
# 27.12      101
# 27.80      100
# 24.96      100
#          ...
# 58.23        1
# 48.18        1
# 55.57        1
# 57.07        1
# 60.52        1
# Name: count, Length: 4247, dtype: int64
#
#
# Unique values in 'HbA1c_level':
# [6.6 5.7 5.  4.8 6.5 6.1 6.  5.8 3.5 6.2 4.  4.5 9.  7.  8.8 8.2 7.5 6.8]
#
# Unique value counts in 'HbA1c_level':
# HbA1c_level
# 6.6    8540
# 5.7    8413
# 6.5    8362
# 5.8    8321
# 6.0    8295
# 6.2    8269
# 6.1    8048
# 3.5    7662
# 4.8    7597
# 4.5    7585
# 4.0    7542
# 5.0    7471
# 8.8     661
# 8.2     661
# 9.0     654
# 7.5     643
# 6.8     642
# 7.0     634
# Name: count, dtype: int64
#
#
# Unique values in 'blood_glucose_level':
# [140  80 158 155  85 200 145 100 130 160 126 159  90 260 220 300 280 240]
#
# Unique value counts in 'blood_glucose_level':
# blood_glucose_level
# 130    7794
# 159    7759
# 140    7732
# 160    7712
# 126    7702
# 145    7679
# 200    7600
# 155    7575
# 90     7112
# 80     7106
# 158    7026
# 100    7025
# 85     6901
# 280     729
# 300     674
# 240     636
# 260     635
# 220     603
# Name: count, dtype: int64
#
#
# Unique values in 'diabetes':
# [0 1]
#
# Unique value counts in 'diabetes':
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64
#
#
# Unique values in 'diabetes_status':
# ['stress induced type 2 diabetic' 'stress induced prediabetic'
#  'non diabetic' 'diabetic' 'prediabetic']
#
# Unique value counts in 'diabetes_status':
# diabetes_status
# stress induced prediabetic        38037
# non diabetic                      37857
# stress induced type 2 diabetic    15606
# diabetic                           5191
# prediabetic                        3309
# Name: count, dtype: int64

# %%
# Drop the diabetes and hba1c columns
df = df.drop('diabetes', axis=1)

# %%
# Drop records where gender is 'Other'
df = df[df['gender'] != 'Other']

# %%
# One-hot encode categorical features
df = pd.get_dummies(df, columns=['gender', 'smoking_history'], drop_first=False)

# %%
# Define the order of categories for diabetes_status
status_order = ['non diabetic', 'stress induced prediabetic', 'stress induced type 2 diabetic', 'prediabetic', 'diabetic']

# Create a mapping for the specified order
status_mapping = {status: i for i, status in enumerate(status_order)}

# Map 'diabetes_status' to the numeric encoding
df['diabetes_status'] = df['diabetes_status'].map(status_mapping)

# %%
# Move the encoded 'diabetes_status' to the right
cols = df.columns.tolist()
cols.append(cols.pop(cols.index('diabetes_status')))
df = df[cols]

# %%
# Data re inspection: view first 10 rows and shape
print("First ten rows of the dataset:")
display(df.head(10))

print("\nDataset dimensions:")
print(f"Number of rows: {df.shape[0]}, Number of columns: {df.shape[1]}")
# Out:
# First ten rows of the dataset:
#     age  hypertension  heart_disease    bmi  HbA1c_level  blood_glucose_level  \
# 0  80.0             0              1  25.19          6.6                  140
# 1  54.0             0              0  27.32          6.6                   80
# 2  28.0             0              0  27.32          5.7                  158
# 3  36.0             0              0  23.45          5.0                  155
# 4  76.0             1              1  20.14          4.8                  155
# 5  20.0             0              0  27.32          6.6                   85
# 6  44.0             0              0  19.31          6.5                  200
# 7  79.0             0              0  23.86          5.7                   85
# 8  42.0             0              0  33.64          4.8                  145
# 9  32.0             0              0  27.32          5.0                  100
#
#    gender_Female  gender_Male  smoking_history_No Info  \
# 0           True        False                    False
# 1           True        False                     True
# 2          False         True                    False
# 3           True        False                    False
# 4          False         True                    False
# 5           True        False                    False
# 6           True        False                    False
# 7           True        False                     True
# 8          False         True                    False
# 9           True        False                    False
#
#    smoking_history_current  smoking_history_ever  smoking_history_former  \
# 0                    False                 False                   False
# 1                    False                 False                   False
# 2                    False                 False                   False
# 3                     True                 False                   False
# 4                     True                 False                   False
# 5                    False                 False                   False
# 6                    False                 False                   False
# 7                    False                 False                   False
# 8                    False                 False                   False
# 9                    False                 False                   False
#
#    smoking_history_never  smoking_history_not current  diabetes_status
# 0                   True                        False                2
# 1                  False                        False                2
# 2                   True                        False                1
# 3                  False                        False                0
# 4                  False                        False                0
# 5                   True                        False                2
# 6                   True                        False                4
# 7                  False                        False                1
# 8                   True                        False                0
# 9                   True                        False                0
# Dataset dimensions:
# Number of rows: 99982, Number of columns: 15

# %%
# Data re inspection: data information
print("\nDataset information:")
df.info()
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99982 entries, 0 to 99999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          99982 non-null  float64
#  1   hypertension                 99982 non-null  int64
#  2   heart_disease                99982 non-null  int64
#  3   bmi                          99982 non-null  float64
#  4   HbA1c_level                  99982 non-null  float64
#  5   blood_glucose_level          99982 non-null  int64
#  6   gender_Female                99982 non-null  bool
#  7   gender_Male                  99982 non-null  bool
#  8   smoking_history_No Info      99982 non-null  bool
#  9   smoking_history_current      99982 non-null  bool
#  10  smoking_history_ever         99982 non-null  bool
#  11  smoking_history_former       99982 non-null  bool
#  12  smoking_history_never        99982 non-null  bool
#  13  smoking_history_not current  99982 non-null  bool
#  14  diabetes_status              99982 non-null  int64
# dtypes: bool(8), float64(3), int64(4)
# memory usage: 6.9 MB

# %%
# Data re inspection: statistical summary
print("\nStatistical summary:")
display(df.describe())
# Out:
# Statistical summary:
#                 age  hypertension  heart_disease           bmi   HbA1c_level  \
# count  99982.000000  99982.000000   99982.000000  99982.000000  99982.000000
# mean      41.888076      0.074863       0.039427     27.320757      5.527529
# std       22.517206      0.263172       0.194610      6.636853      1.070665
# min        0.080000      0.000000       0.000000     10.010000      3.500000
# 25%       24.000000      0.000000       0.000000     23.630000      4.800000
# 50%       43.000000      0.000000       0.000000     27.320000      5.800000
# 75%       60.000000      0.000000       0.000000     29.580000      6.200000
# max       80.000000      1.000000       1.000000     95.690000      9.000000
#
#        blood_glucose_level  diabetes_status
# count         99982.000000     99982.000000
# mean            138.057810         0.999440
# std              40.709469         1.065033
# min              80.000000         0.000000
# 25%             100.000000         0.000000
# 50%             140.000000         1.000000
# 75%             159.000000         1.000000
# max             300.000000         4.000000

# %%
# Data re inspection: unique values and counts
for column in df.columns:
    print(f"Unique values in '{column}':")
    print(df[column].unique())
    print(f"\nUnique value counts in '{column}':")
    print(df[column].value_counts())
    print("\n")
# Out:
# Unique values in 'age':
# [80.   54.   28.   36.   76.   20.   44.   79.   42.   32.   53.   78.
#  67.   15.   37.   40.    5.   69.   72.    4.   30.   45.   43.   50.
#  41.   26.   34.   73.   77.   66.   29.   60.   38.    3.   57.   74.
#  19.   46.   21.   59.   27.   13.   56.    2.    7.   11.    6.   55.
#   9.   62.   47.   12.   68.   75.   22.   58.   18.   24.   17.   25.
#   0.08 33.   16.   61.   31.    8.   49.   39.   65.   14.   70.    0.56
#  48.   51.   71.    0.88 64.   63.   52.    0.16 10.   35.   23.    0.64
#   1.16  1.64  0.72  1.88  1.32  0.8   1.24  1.    1.8   0.48  1.56  1.08
#   0.24  1.4   0.4   0.32  1.72  1.48]
#
# Unique value counts in 'age':
# age
# 80.00    5621
# 51.00    1619
# 47.00    1572
# 48.00    1568
# 49.00    1541
#          ...
# 0.48       83
# 1.00       83
# 0.40       66
# 0.16       59
# 0.08       36
# Name: count, Length: 102, dtype: int64
#
#
# Unique values in 'hypertension':
# [0 1]
#
# Unique value counts in 'hypertension':
# hypertension
# 0    92497
# 1     7485
# Name: count, dtype: int64
#
#
# Unique values in 'heart_disease':
# [1 0]
#
# Unique value counts in 'heart_disease':
# heart_disease
# 0    96040
# 1     3942
# Name: count, dtype: int64
#
#
# Unique values in 'bmi':
# [25.19 27.32 23.45 ... 59.42 44.39 60.52]
#
# Unique value counts in 'bmi':
# bmi
# 27.32    25488
# 23.00      103
# 27.12      101
# 27.80      100
# 24.96      100
#          ...
# 53.28        1
# 55.38        1
# 40.26        1
# 51.75        1
# 60.52        1
# Name: count, Length: 4247, dtype: int64
#
#
# Unique values in 'HbA1c_level':
# [6.6 5.7 5.  4.8 6.5 6.1 6.  5.8 3.5 6.2 4.  4.5 9.  7.  8.8 8.2 7.5 6.8]
#
# Unique value counts in 'HbA1c_level':
# HbA1c_level
# 6.6    8537
# 5.7    8412
# 6.5    8362
# 5.8    8321
# 6.0    8294
# 6.2    8267
# 6.1    8044
# 3.5    7659
# 4.8    7597
# 4.5    7584
# 4.0    7541
# 5.0    7469
# 8.8     661
# 8.2     661
# 9.0     654
# 7.5     643
# 6.8     642
# 7.0     634
# Name: count, dtype: int64
#
#
# Unique values in 'blood_glucose_level':
# [140  80 158 155  85 200 145 100 130 160 126 159  90 260 220 300 280 240]
#
# Unique value counts in 'blood_glucose_level':
# blood_glucose_level
# 130    7794
# 159    7756
# 140    7730
# 160    7708
# 126    7700
# 145    7679
# 200    7599
# 155    7575
# 90     7110
# 80     7105
# 100    7025
# 158    7024
# 85     6900
# 280     729
# 300     674
# 240     636
# 260     635
# 220     603
# Name: count, dtype: int64
#
#
# Unique values in 'gender_Female':
# [ True False]
#
# Unique value counts in 'gender_Female':
# gender_Female
# True     58552
# False    41430
# Name: count, dtype: int64
#
#
# Unique values in 'gender_Male':
# [False  True]
#
# Unique value counts in 'gender_Male':
# gender_Male
# False    58552
# True     41430
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_No Info':
# [False  True]
#
# Unique value counts in 'smoking_history_No Info':
# smoking_history_No Info
# False    64172
# True     35810
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_current':
# [False  True]
#
# Unique value counts in 'smoking_history_current':
# smoking_history_current
# False    90696
# True      9286
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_ever':
# [False  True]
#
# Unique value counts in 'smoking_history_ever':
# smoking_history_ever
# False    95979
# True      4003
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_former':
# [False  True]
#
# Unique value counts in 'smoking_history_former':
# smoking_history_former
# False    90630
# True      9352
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_never':
# [ True False]
#
# Unique value counts in 'smoking_history_never':
# smoking_history_never
# False    64890
# True     35092
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_not current':
# [False  True]
#
# Unique value counts in 'smoking_history_not current':
# smoking_history_not current
# False    93543
# True      6439
# Name: count, dtype: int64
#
#
# Unique values in 'diabetes_status':
# [2 1 0 4 3]
#
# Unique value counts in 'diabetes_status':
# diabetes_status
# 1    38029
# 0    37850
# 2    15603
# 4     5191
# 3     3309
# Name: count, dtype: int64

# %%
# Separate features and target
X = df.drop(columns=['diabetes_status'])
y = df['diabetes_status']

# %%
# Initialize SMOTE
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

# %%
# Initialize KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# List of models to evaluate
models = [
    AdaBoostClassifier(),
    KNeighborsClassifier(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    VotingClassifier(estimators=[
        ('knn', KNeighborsClassifier()),
        ('rf', RandomForestClassifier())
    ], voting='hard'),
    StackingClassifier(estimators=[
        ('knn', KNeighborsClassifier()),
        ('rf', RandomForestClassifier())
    ], final_estimator=LogisticRegression()),
]

# %%
def evaluate_models(models, X, y, kf):
    results = {}
    
    for model in models:
        model_name = type(model).__name__
        print(f"Evaluating {model_name}...")
        
        fold_accuracies = []
        fold_f1_scores = []
        fold_reports = []
        
        for fold, (train_index, test_index) in enumerate(kf.split(X)):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]
            
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            
            accuracy = accuracy_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred, average='weighted')
            report = classification_report(y_test, y_pred)
            
            fold_accuracies.append(accuracy)
            fold_f1_scores.append(f1)
            fold_reports.append(report)
            
            print(f"Fold {fold + 1} - Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}")
            print(f"Classification Report for Fold {fold + 1}:\n{report}\n")
        
        mean_accuracy = np.mean(fold_accuracies)
        std_accuracy = np.std(fold_accuracies)
        mean_f1 = np.mean(fold_f1_scores)
        std_f1 = np.std(fold_f1_scores)
        
        print(f"\n{model_name} - Mean Accuracy: {mean_accuracy:.4f} (± {std_accuracy:.4f}), Mean F1 Score: {mean_f1:.4f} (± {std_f1:.4f})\n")
        
        results[model_name] = {
            'mean_accuracy': mean_accuracy,
            'std_accuracy': std_accuracy,
            'mean_f1': mean_f1,
            'std_f1': std_f1,
            'reports': fold_reports
        }
    
    return results

# %%
# Call the function with the updated list of models, features, target, and KFold object
results = evaluate_models(models, X_res, y_res, kf)
# Out:
# Evaluating AdaBoostClassifier...
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Fold 1 - Accuracy: 0.5935, F1 Score: 0.4594
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7583
#            1       0.00      0.00      0.00      7703
#            2       0.49      1.00      0.66      7362
#            3       0.50      1.00      0.66      7626
#            4       0.00      0.00      0.00      7755
#
#     accuracy                           0.59     38029
#    macro avg       0.40      0.60      0.46     38029
# weighted avg       0.39      0.59      0.46     38029
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Fold 2 - Accuracy: 0.5974, F1 Score: 0.4640
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7650
#            1       0.50      1.00      0.66      7541
#            2       0.00      0.00      0.00      7678
#            3       0.00      0.00      0.00      7631
#            4       0.50      1.00      0.66      7529
#
#     accuracy                           0.60     38029
#    macro avg       0.40      0.60      0.47     38029
# weighted avg       0.40      0.60      0.46     38029
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Fold 3 - Accuracy: 0.5977, F1 Score: 0.4644
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7683
#            1       0.00      0.00      0.00      7585
#            2       0.00      0.00      0.00      7714
#            3       0.50      1.00      0.67      7544
#            4       0.49      1.00      0.66      7503
#
#     accuracy                           0.60     38029
#    macro avg       0.40      0.60      0.47     38029
# weighted avg       0.40      0.60      0.46     38029
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Fold 4 - Accuracy: 0.5967, F1 Score: 0.4626
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7479
#            1       0.00      0.00      0.00      7676
#            2       0.00      0.00      0.00      7662
#            3       0.50      1.00      0.66      7556
#            4       0.50      1.00      0.67      7656
#
#     accuracy                           0.60     38029
#    macro avg       0.40      0.60      0.47     38029
# weighted avg       0.40      0.60      0.46     38029
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\david\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 5 - Accuracy: 0.5981, F1 Score: 0.4646
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7634
#            1       0.50      1.00      0.66      7524
#            2       0.00      0.00      0.00      7613
#            3       0.00      0.00      0.00      7672
#            4       0.50      1.00      0.67      7586
#
#     accuracy                           0.60     38029
#    macro avg       0.40      0.60      0.47     38029
# weighted avg       0.40      0.60      0.46     38029
#
#
#
# AdaBoostClassifier - Mean Accuracy: 0.5967 (± 0.0016), Mean F1 Score: 0.4630 (± 0.0019)
#
# Evaluating KNeighborsClassifier...
# Fold 1 - Accuracy: 0.8481, F1 Score: 0.8470
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      7583
#            1       0.72      0.65      0.68      7703
#            2       0.75      0.81      0.78      7362
#            3       0.87      0.95      0.91      7626
#            4       0.95      0.95      0.95      7755
#
#     accuracy                           0.85     38029
#    macro avg       0.85      0.85      0.85     38029
# weighted avg       0.85      0.85      0.85     38029
#
#
# Fold 2 - Accuracy: 0.8470, F1 Score: 0.8461
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      7650
#            1       0.70      0.65      0.67      7541
#            2       0.76      0.81      0.78      7678
#            3       0.87      0.95      0.91      7631
#            4       0.95      0.95      0.95      7529
#
#     accuracy                           0.85     38029
#    macro avg       0.85      0.85      0.85     38029
# weighted avg       0.85      0.85      0.85     38029
#
#
# Fold 3 - Accuracy: 0.8451, F1 Score: 0.8438
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      7683
#            1       0.71      0.65      0.68      7585
#            2       0.76      0.80      0.78      7714
#            3       0.86      0.95      0.91      7544
#            4       0.94      0.95      0.95      7503
#
#     accuracy                           0.85     38029
#    macro avg       0.84      0.85      0.84     38029
# weighted avg       0.84      0.85      0.84     38029
#
#
# Fold 4 - Accuracy: 0.8476, F1 Score: 0.8461
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      7479
#            1       0.71      0.64      0.68      7676
#            2       0.76      0.81      0.78      7662
#            3       0.87      0.95      0.91      7556
#            4       0.95      0.95      0.95      7656
#
#     accuracy                           0.85     38029
#    macro avg       0.85      0.85      0.85     38029
# weighted avg       0.85      0.85      0.85     38029
#
#
# Fold 5 - Accuracy: 0.8476, F1 Score: 0.8467
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      7634
#            1       0.71      0.65      0.68      7524
#            2       0.76      0.81      0.79      7613
#            3       0.87      0.95      0.91      7672
#            4       0.95      0.94      0.95      7586
#
#     accuracy                           0.85     38029
#    macro avg       0.85      0.85      0.85     38029
# weighted avg       0.85      0.85      0.85     38029
#
#
#
# KNeighborsClassifier - Mean Accuracy: 0.8471 (± 0.0011), Mean F1 Score: 0.8459 (± 0.0011)
#
# Evaluating DecisionTreeClassifier...
# Fold 1 - Accuracy: 0.9676, F1 Score: 0.9676
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7583
#            1       0.95      0.95      0.95      7703
#            2       0.97      0.97      0.97      7362
#            3       0.95      0.95      0.95      7626
#            4       0.97      0.97      0.97      7755
#
#     accuracy                           0.97     38029
#    macro avg       0.97      0.97      0.97     38029
# weighted avg       0.97      0.97      0.97     38029
#
#
# Fold 2 - Accuracy: 0.9693, F1 Score: 0.9693
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7650
#            1       0.96      0.95      0.95      7541
#            2       0.97      0.97      0.97      7678
#            3       0.95      0.96      0.95      7631
#            4       0.97      0.97      0.97      7529
#
#     accuracy                           0.97     38029
#    macro avg       0.97      0.97      0.97     38029
# weighted avg       0.97      0.97      0.97     38029
#
#
# Fold 3 - Accuracy: 0.9681, F1 Score: 0.9681
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7683
#            1       0.95      0.95      0.95      7585
#            2       0.97      0.97      0.97      7714
#            3       0.95      0.95      0.95      7544
#            4       0.97      0.97      0.97      7503
#
#     accuracy                           0.97     38029
#    macro avg       0.97      0.97      0.97     38029
# weighted avg       0.97      0.97      0.97     38029
#
#
# Fold 4 - Accuracy: 0.9675, F1 Score: 0.9675
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7479
#            1       0.95      0.94      0.95      7676
#            2       0.97      0.97      0.97      7662
#            3       0.94      0.95      0.95      7556
#            4       0.97      0.97      0.97      7656
#
#     accuracy                           0.97     38029
#    macro avg       0.97      0.97      0.97     38029
# weighted avg       0.97      0.97      0.97     38029
#
#
# Fold 5 - Accuracy: 0.9672, F1 Score: 0.9672
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7634
#            1       0.95      0.94      0.95      7524
#            2       0.97      0.97      0.97      7613
#            3       0.95      0.95      0.95      7672
#            4       0.97      0.97      0.97      7586
#
#     accuracy                           0.97     38029
#    macro avg       0.97      0.97      0.97     38029
# weighted avg       0.97      0.97      0.97     38029
#
#
#
# DecisionTreeClassifier - Mean Accuracy: 0.9680 (± 0.0007), Mean F1 Score: 0.9680 (± 0.0007)
#
# Evaluating RandomForestClassifier...
# Fold 1 - Accuracy: 0.9784, F1 Score: 0.9784
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7583
#            1       0.96      0.98      0.97      7703
#            2       0.96      0.99      0.98      7362
#            3       0.98      0.96      0.97      7626
#            4       0.99      0.97      0.98      7755
#
#     accuracy                           0.98     38029
#    macro avg       0.98      0.98      0.98     38029
# weighted avg       0.98      0.98      0.98     38029
#
#
# Fold 2 - Accuracy: 0.9794, F1 Score: 0.9794
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7650
#            1       0.96      0.98      0.97      7541
#            2       0.97      0.99      0.98      7678
#            3       0.98      0.96      0.97      7631
#            4       0.99      0.97      0.98      7529
#
#     accuracy                           0.98     38029
#    macro avg       0.98      0.98      0.98     38029
# weighted avg       0.98      0.98      0.98     38029
#
#
# Fold 3 - Accuracy: 0.9804, F1 Score: 0.9804
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7683
#            1       0.96      0.98      0.97      7585
#            2       0.97      0.99      0.98      7714
#            3       0.98      0.96      0.97      7544
#            4       0.99      0.97      0.98      7503
#
#     accuracy                           0.98     38029
#    macro avg       0.98      0.98      0.98     38029
# weighted avg       0.98      0.98      0.98     38029
#
#
# Fold 4 - Accuracy: 0.9804, F1 Score: 0.9804
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7479
#            1       0.96      0.98      0.97      7676
#            2       0.97      0.99      0.98      7662
#            3       0.98      0.95      0.97      7556
#            4       0.99      0.97      0.98      7656
#
#     accuracy                           0.98     38029
#    macro avg       0.98      0.98      0.98     38029
# weighted avg       0.98      0.98      0.98     38029
#
#
# Fold 5 - Accuracy: 0.9790, F1 Score: 0.9790
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7634
#            1       0.96      0.98      0.97      7524
#            2       0.97      0.99      0.98      7613
#            3       0.98      0.96      0.97      7672
#            4       0.99      0.96      0.98      7586
#
#     accuracy                           0.98     38029
#    macro avg       0.98      0.98      0.98     38029
# weighted avg       0.98      0.98      0.98     38029
#
#
#
# RandomForestClassifier - Mean Accuracy: 0.9795 (± 0.0008), Mean F1 Score: 0.9795 (± 0.0008)
#
# Evaluating VotingClassifier...
# Fold 1 - Accuracy: 0.9285, F1 Score: 0.9290
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7583
#            1       0.82      0.94      0.88      7703
#            2       0.93      0.86      0.89      7362
#            3       0.96      0.93      0.94      7626
#            4       1.00      0.92      0.96      7755
#
#     accuracy                           0.93     38029
#    macro avg       0.93      0.93      0.93     38029
# weighted avg       0.93      0.93      0.93     38029
#
#
# Fold 2 - Accuracy: 0.9277, F1 Score: 0.9283
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7650
#            1       0.81      0.94      0.87      7541
#            2       0.93      0.85      0.89      7678
#            3       0.96      0.93      0.95      7631
#            4       1.00      0.92      0.96      7529
#
#     accuracy                           0.93     38029
#    macro avg       0.93      0.93      0.93     38029
# weighted avg       0.93      0.93      0.93     38029
#
#
# Fold 3 - Accuracy: 0.9288, F1 Score: 0.9294
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7683
#            1       0.81      0.94      0.87      7585
#            2       0.94      0.85      0.89      7714
#            3       0.96      0.93      0.95      7544
#            4       1.00      0.93      0.96      7503
#
#     accuracy                           0.93     38029
#    macro avg       0.93      0.93      0.93     38029
# weighted avg       0.93      0.93      0.93     38029
#
#
# Fold 4 - Accuracy: 0.9277, F1 Score: 0.9283
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7479
#            1       0.82      0.94      0.87      7676
#            2       0.94      0.85      0.89      7662
#            3       0.96      0.93      0.95      7556
#            4       1.00      0.92      0.96      7656
#
#     accuracy                           0.93     38029
#    macro avg       0.93      0.93      0.93     38029
# weighted avg       0.93      0.93      0.93     38029
#
#
# Fold 5 - Accuracy: 0.9282, F1 Score: 0.9289
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7634
#            1       0.81      0.94      0.87      7524
#            2       0.93      0.86      0.89      7613
#            3       0.96      0.93      0.95      7672
#            4       1.00      0.92      0.96      7586
#
#     accuracy                           0.93     38029
#    macro avg       0.93      0.93      0.93     38029
# weighted avg       0.93      0.93      0.93     38029
#
#
#
# VotingClassifier - Mean Accuracy: 0.9282 (± 0.0004), Mean F1 Score: 0.9288 (± 0.0004)
#
# Evaluating StackingClassifier...
# Fold 1 - Accuracy: 0.9831, F1 Score: 0.9831
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7583
#            1       0.97      0.97      0.97      7703
#            2       0.98      0.99      0.99      7362
#            3       0.97      0.97      0.97      7626
#            4       0.99      0.99      0.99      7755
#
#     accuracy                           0.98     38029
#    macro avg       0.98      0.98      0.98     38029
# weighted avg       0.98      0.98      0.98     38029
#
#
# Fold 2 - Accuracy: 0.9842, F1 Score: 0.9842
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7650
#            1       0.97      0.97      0.97      7541
#            2       0.98      0.99      0.99      7678
#            3       0.97      0.97      0.97      7631
#            4       0.99      0.98      0.99      7529
#
#     accuracy                           0.98     38029
#    macro avg       0.98      0.98      0.98     38029
# weighted avg       0.98      0.98      0.98     38029
#
#
# Fold 3 - Accuracy: 0.9837, F1 Score: 0.9837
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7683
#            1       0.97      0.97      0.97      7585
#            2       0.99      0.99      0.99      7714
#            3       0.97      0.97      0.97      7544
#            4       0.99      0.99      0.99      7503
#
#     accuracy                           0.98     38029
#    macro avg       0.98      0.98      0.98     38029
# weighted avg       0.98      0.98      0.98     38029
#
#
# Fold 4 - Accuracy: 0.9836, F1 Score: 0.9836
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7479
#            1       0.97      0.97      0.97      7676
#            2       0.99      0.99      0.99      7662
#            3       0.97      0.97      0.97      7556
#            4       0.99      0.99      0.99      7656
#
#     accuracy                           0.98     38029
#    macro avg       0.98      0.98      0.98     38029
# weighted avg       0.98      0.98      0.98     38029
#
#
# Fold 5 - Accuracy: 0.9832, F1 Score: 0.9832
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7634
#            1       0.97      0.97      0.97      7524
#            2       0.98      0.99      0.99      7613
#            3       0.97      0.97      0.97      7672
#            4       0.99      0.98      0.99      7586
#
#     accuracy                           0.98     38029
#    macro avg       0.98      0.98      0.98     38029
# weighted avg       0.98      0.98      0.98     38029
#
#
#
# StackingClassifier - Mean Accuracy: 0.9836 (± 0.0004), Mean F1 Score: 0.9836 (± 0.0004)
