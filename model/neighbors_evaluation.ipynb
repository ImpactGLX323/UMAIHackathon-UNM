# %%
# Import libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, accuracy_score, f1_score

from imblearn.over_sampling import SMOTE

from sklearn.neighbors import KNeighborsClassifier, NearestCentroid, RadiusNeighborsClassifier

# %%
# Load the processed dataset
df = pd.read_csv('../data/preprocessed/with_diabetes_status/dataset_with_diabetes_status.csv')

# %%
# Drop the diabetes and hba1c columns
df = df.drop('diabetes', axis=1)

# %%
# Drop records where gender is 'Other'
df = df[df['gender'] != 'Other']

# %%
# One-hot encode categorical features
df = pd.get_dummies(df, columns=['gender', 'smoking_history'], drop_first=False)

# %%
# Define the order of categories for diabetes_status
status_order = ['non diabetic', 'stress induced prediabetic', 'stress induced type 2 diabetic', 'prediabetic', 'diabetic']

# Create a mapping for the specified order
status_mapping = {status: i for i, status in enumerate(status_order)}

# Map 'diabetes_status' to the numeric encoding
df['diabetes_status'] = df['diabetes_status'].map(status_mapping)

# %%
# Move the encoded 'diabetes_status' to the right
cols = df.columns.tolist()
cols.append(cols.pop(cols.index('diabetes_status')))
df = df[cols]

# %%
# Separate features and target
X = df.drop(columns=['diabetes_status'])
y = df['diabetes_status']

# %%
# Initialize SMOTE
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

# %%
# Initialize KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# List of models to evaluate
models = [
    KNeighborsClassifier(),
    NearestCentroid(),
    RadiusNeighborsClassifier(),
]

# %%
def evaluate_models(models, X, y, kf):
    results = {}
    
    for model in models:
        model_name = type(model).__name__
        print(f"Evaluating {model_name}...")
        
        fold_accuracies = []
        fold_f1_scores = []
        fold_reports = []
        
        for fold, (train_index, test_index) in enumerate(kf.split(X)):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]
            
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            
            accuracy = accuracy_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred, average='weighted')
            report = classification_report(y_test, y_pred)
            
            fold_accuracies.append(accuracy)
            fold_f1_scores.append(f1)
            fold_reports.append(report)
            
            print(f"Fold {fold + 1} - Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}")
            print(f"Classification Report for Fold {fold + 1}:\n{report}\n")
        
        mean_accuracy = np.mean(fold_accuracies)
        std_accuracy = np.std(fold_accuracies)
        mean_f1 = np.mean(fold_f1_scores)
        std_f1 = np.std(fold_f1_scores)
        
        print(f"\n{model_name} - Mean Accuracy: {mean_accuracy:.4f} (± {std_accuracy:.4f}), Mean F1 Score: {mean_f1:.4f} (± {std_f1:.4f})\n")
        
        results[model_name] = {
            'mean_accuracy': mean_accuracy,
            'std_accuracy': std_accuracy,
            'mean_f1': mean_f1,
            'std_f1': std_f1,
            'reports': fold_reports
        }
    
    return results

# %%
# Call the function with the updated list of models, features, target, and KFold object
results = evaluate_models(models, X_res, y_res, kf)
# Out:
# Evaluating KNeighborsClassifier...
# Fold 1 - Accuracy: 0.8481, F1 Score: 0.8470
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      7583
#            1       0.72      0.65      0.68      7703
#            2       0.75      0.81      0.78      7362
#            3       0.87      0.95      0.91      7626
#            4       0.95      0.95      0.95      7755
#
#     accuracy                           0.85     38029
#    macro avg       0.85      0.85      0.85     38029
# weighted avg       0.85      0.85      0.85     38029
#
#
# Fold 2 - Accuracy: 0.8470, F1 Score: 0.8461
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      7650
#            1       0.70      0.65      0.67      7541
#            2       0.76      0.81      0.78      7678
#            3       0.87      0.95      0.91      7631
#            4       0.95      0.95      0.95      7529
#
#     accuracy                           0.85     38029
#    macro avg       0.85      0.85      0.85     38029
# weighted avg       0.85      0.85      0.85     38029
#
#
# Fold 3 - Accuracy: 0.8451, F1 Score: 0.8438
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      7683
#            1       0.71      0.65      0.68      7585
#            2       0.76      0.80      0.78      7714
#            3       0.86      0.95      0.91      7544
#            4       0.94      0.95      0.95      7503
#
#     accuracy                           0.85     38029
#    macro avg       0.84      0.85      0.84     38029
# weighted avg       0.84      0.85      0.84     38029
#
#
# Fold 4 - Accuracy: 0.8476, F1 Score: 0.8461
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      7479
#            1       0.71      0.64      0.68      7676
#            2       0.76      0.81      0.78      7662
#            3       0.87      0.95      0.91      7556
#            4       0.95      0.95      0.95      7656
#
#     accuracy                           0.85     38029
#    macro avg       0.85      0.85      0.85     38029
# weighted avg       0.85      0.85      0.85     38029
#
#
# Fold 5 - Accuracy: 0.8476, F1 Score: 0.8467
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      7634
#            1       0.71      0.65      0.68      7524
#            2       0.76      0.81      0.79      7613
#            3       0.87      0.95      0.91      7672
#            4       0.95      0.94      0.95      7586
#
#     accuracy                           0.85     38029
#    macro avg       0.85      0.85      0.85     38029
# weighted avg       0.85      0.85      0.85     38029
#
#
#
# KNeighborsClassifier - Mean Accuracy: 0.8471 (± 0.0011), Mean F1 Score: 0.8459 (± 0.0011)
#
# Evaluating NearestCentroid...
# Fold 1 - Accuracy: 0.3242, F1 Score: 0.3243
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       0.31      0.35      0.33      7583
#            1       0.20      0.28      0.23      7703
#            2       0.35      0.37      0.36      7362
#            3       0.38      0.19      0.26      7626
#            4       0.45      0.43      0.44      7755
#
#     accuracy                           0.32     38029
#    macro avg       0.34      0.32      0.32     38029
# weighted avg       0.34      0.32      0.32     38029
#
#
# Fold 2 - Accuracy: 0.3351, F1 Score: 0.3298
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       0.94      0.22      0.35      7650
#            1       0.22      0.42      0.29      7541
#            2       0.33      0.46      0.39      7678
#            3       0.30      0.14      0.19      7631
#            4       0.42      0.44      0.43      7529
#
#     accuracy                           0.34     38029
#    macro avg       0.44      0.34      0.33     38029
# weighted avg       0.44      0.34      0.33     38029
#
#
# Fold 3 - Accuracy: 0.3128, F1 Score: 0.3052
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       0.34      0.34      0.34      7683
#            1       0.17      0.21      0.19      7585
#            2       0.35      0.44      0.39      7714
#            3       0.30      0.13      0.18      7544
#            4       0.41      0.44      0.42      7503
#
#     accuracy                           0.31     38029
#    macro avg       0.32      0.31      0.30     38029
# weighted avg       0.32      0.31      0.31     38029
#
#
# Fold 4 - Accuracy: 0.3906, F1 Score: 0.3959
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       0.98      0.48      0.64      7479
#            1       0.27      0.44      0.33      7676
#            2       0.34      0.46      0.39      7662
#            3       0.31      0.14      0.19      7556
#            4       0.42      0.44      0.43      7656
#
#     accuracy                           0.39     38029
#    macro avg       0.46      0.39      0.40     38029
# weighted avg       0.46      0.39      0.40     38029
#
#
# Fold 5 - Accuracy: 0.3599, F1 Score: 0.3627
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       0.95      0.36      0.52      7634
#            1       0.24      0.43      0.31      7524
#            2       0.32      0.44      0.37      7613
#            3       0.32      0.14      0.19      7672
#            4       0.41      0.44      0.42      7586
#
#     accuracy                           0.36     38029
#    macro avg       0.45      0.36      0.36     38029
# weighted avg       0.45      0.36      0.36     38029
#
#
#
# NearestCentroid - Mean Accuracy: 0.3445 (± 0.0278), Mean F1 Score: 0.3436 (± 0.0321)
#
# Evaluating RadiusNeighborsClassifier...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Call the function with the updated list of models, features, target, and KFold object
# ----> 2 results = evaluate_models(models, X_res, y_res, kf)
#
# Cell In[12], line 17, in evaluate_models(models, X, y, kf)
#      14 y_train, y_test = y.iloc[train_index], y.iloc[test_index]
#      16 model.fit(X_train, y_train)
# ---> 17 y_pred = model.predict(X_test)
#      19 accuracy = accuracy_score(y_test, y_pred)
#      20 f1 = f1_score(y_test, y_pred, average='weighted')
#
# File ~\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:693, in RadiusNeighborsClassifier.predict(self, X)
#     678 def predict(self, X):
#     679     """Predict the class labels for the provided data.
#     680
#     681     Parameters
#    (...)
#     690         Class labels for each data sample.
#     691     """
# --> 693     probs = self.predict_proba(X)
#     694     classes_ = self.classes_
#     696     if not self.outputs_2d_:
#
# File ~\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:782, in RadiusNeighborsClassifier.predict_proba(self, X)
#     779     classes_ = [self.classes_]
#     781 if self.outlier_label_ is None and outliers.size > 0:
# --> 782     raise ValueError(
#     783         "No neighbors found for test samples %r, "
#     784         "you can try using larger radius, "
#     785         "giving a label for outliers, "
#     786         "or considering removing them from your dataset." % outliers
#     787     )
#     789 weights = _get_weights(neigh_dist, self.weights)
#     790 if weights is not None:
#
# ValueError: No neighbors found for test samples array([    1,     2,     3, ..., 38005, 38022, 38026], dtype=int64), you can try using larger radius, giving a label for outliers, or considering removing them from your dataset.
