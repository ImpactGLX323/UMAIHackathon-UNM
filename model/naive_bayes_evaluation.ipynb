# %%
# Import libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, accuracy_score, f1_score

from imblearn.over_sampling import SMOTE

from sklearn.naive_bayes import BernoulliNB, CategoricalNB, ComplementNB, GaussianNB, MultinomialNB

# %%
# Load the processed dataset
df = pd.read_csv('../data/preprocessed/with_diabetes_status/dataset_with_diabetes_status.csv')

# %%
# Drop the diabetes and hba1c columns
df = df.drop('diabetes', axis=1)

# %%
# Drop records where gender is 'Other'
df = df[df['gender'] != 'Other']

# %%
# One-hot encode categorical features
df = pd.get_dummies(df, columns=['gender', 'smoking_history'], drop_first=False)

# %%
# Define the order of categories for diabetes_status
status_order = ['non diabetic', 'stress induced prediabetic', 'stress induced type 2 diabetic', 'prediabetic', 'diabetic']

# Create a mapping for the specified order
status_mapping = {status: i for i, status in enumerate(status_order)}

# Map 'diabetes_status' to the numeric encoding
df['diabetes_status'] = df['diabetes_status'].map(status_mapping)

# %%
# Move the encoded 'diabetes_status' to the right
cols = df.columns.tolist()
cols.append(cols.pop(cols.index('diabetes_status')))
df = df[cols]

# %%
# Separate features and target
X = df.drop(columns=['diabetes_status'])
y = df['diabetes_status']

# %%
# Initialize SMOTE
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

# %%
# Initialize KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# List of models to evaluate
models = [
    BernoulliNB(),
    CategoricalNB(),
    ComplementNB(),
    GaussianNB(),
    MultinomialNB(),
]

# %%
def evaluate_models(models, X, y, kf):
    results = {}
    
    for model in models:
        model_name = type(model).__name__
        print(f"Evaluating {model_name}...")
        
        fold_accuracies = []
        fold_f1_scores = []
        fold_reports = []
        
        for fold, (train_index, test_index) in enumerate(kf.split(X)):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]
            
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            
            accuracy = accuracy_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred, average='weighted')
            report = classification_report(y_test, y_pred)
            
            fold_accuracies.append(accuracy)
            fold_f1_scores.append(f1)
            fold_reports.append(report)
            
            print(f"Fold {fold + 1} - Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}")
            print(f"Classification Report for Fold {fold + 1}:\n{report}\n")
        
        mean_accuracy = np.mean(fold_accuracies)
        std_accuracy = np.std(fold_accuracies)
        mean_f1 = np.mean(fold_f1_scores)
        std_f1 = np.std(fold_f1_scores)
        
        print(f"\n{model_name} - Mean Accuracy: {mean_accuracy:.4f} (± {std_accuracy:.4f}), Mean F1 Score: {mean_f1:.4f} (± {std_f1:.4f})\n")
        
        results[model_name] = {
            'mean_accuracy': mean_accuracy,
            'std_accuracy': std_accuracy,
            'mean_f1': mean_f1,
            'std_f1': std_f1,
            'reports': fold_reports
        }
    
    return results

# %%
# Call the function with the updated list of models, features, target, and KFold object
results = evaluate_models(models, X_res, y_res, kf)
# Out:
# Evaluating BernoulliNB...
# Fold 1 - Accuracy: 0.3015, F1 Score: 0.2623
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       0.31      0.52      0.39      7583
#            1       0.32      0.00      0.01      7703
#            2       0.28      0.29      0.29      7362
#            3       0.32      0.46      0.38      7626
#            4       0.27      0.23      0.25      7755
#
#     accuracy                           0.30     38029
#    macro avg       0.30      0.30      0.26     38029
# weighted avg       0.30      0.30      0.26     38029
#
#
# Fold 2 - Accuracy: 0.2969, F1 Score: 0.2775
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       0.30      0.47      0.37      7650
#            1       0.33      0.05      0.09      7541
#            2       0.28      0.28      0.28      7678
#            3       0.39      0.39      0.39      7631
#            4       0.22      0.29      0.25      7529
#
#     accuracy                           0.30     38029
#    macro avg       0.31      0.30      0.28     38029
# weighted avg       0.31      0.30      0.28     38029
#
#
# Fold 3 - Accuracy: 0.2975, F1 Score: 0.2771
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       0.31      0.47      0.37      7683
#            1       0.31      0.05      0.09      7585
#            2       0.29      0.28      0.28      7714
#            3       0.38      0.39      0.39      7544
#            4       0.23      0.29      0.25      7503
#
#     accuracy                           0.30     38029
#    macro avg       0.30      0.30      0.28     38029
# weighted avg       0.30      0.30      0.28     38029
#
#
# Fold 4 - Accuracy: 0.2919, F1 Score: 0.2804
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       0.27      0.23      0.25      7479
#            1       0.32      0.09      0.14      7676
#            2       0.28      0.43      0.34      7662
#            3       0.45      0.41      0.43      7556
#            4       0.21      0.29      0.25      7656
#
#     accuracy                           0.29     38029
#    macro avg       0.31      0.29      0.28     38029
# weighted avg       0.30      0.29      0.28     38029
#
#
# Fold 5 - Accuracy: 0.3018, F1 Score: 0.3042
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       0.34      0.23      0.27      7634
#            1       0.28      0.30      0.29      7524
#            2       0.29      0.29      0.29      7613
#            3       0.45      0.40      0.42      7672
#            4       0.21      0.30      0.25      7586
#
#     accuracy                           0.30     38029
#    macro avg       0.31      0.30      0.30     38029
# weighted avg       0.31      0.30      0.30     38029
#
#
#
# BernoulliNB - Mean Accuracy: 0.2979 (± 0.0036), Mean F1 Score: 0.2803 (± 0.0135)
#
# Evaluating CategoricalNB...
# Fold 1 - Accuracy: 0.7007, F1 Score: 0.6962
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89      7583
#            1       0.62      0.36      0.45      7703
#            2       0.56      0.87      0.68      7362
#            3       0.62      0.81      0.70      7626
#            4       0.87      0.68      0.76      7755
#
#     accuracy                           0.70     38029
#    macro avg       0.73      0.70      0.70     38029
# weighted avg       0.73      0.70      0.70     38029
#
#
# Fold 2 - Accuracy: 0.7070, F1 Score: 0.7017
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89      7650
#            1       0.62      0.35      0.45      7541
#            2       0.57      0.87      0.69      7678
#            3       0.63      0.82      0.71      7631
#            4       0.87      0.69      0.77      7529
#
#     accuracy                           0.71     38029
#    macro avg       0.74      0.71      0.70     38029
# weighted avg       0.74      0.71      0.70     38029
#
#
# Fold 3 - Accuracy: 0.7071, F1 Score: 0.7017
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89      7683
#            1       0.62      0.35      0.45      7585
#            2       0.57      0.86      0.69      7714
#            3       0.62      0.82      0.71      7544
#            4       0.87      0.70      0.77      7503
#
#     accuracy                           0.71     38029
#    macro avg       0.74      0.71      0.70     38029
# weighted avg       0.74      0.71      0.70     38029
#
#
# Fold 4 - Accuracy: 0.7066, F1 Score: 0.7008
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89      7479
#            1       0.62      0.34      0.44      7676
#            2       0.57      0.87      0.69      7662
#            3       0.63      0.82      0.71      7556
#            4       0.88      0.69      0.78      7656
#
#     accuracy                           0.71     38029
#    macro avg       0.74      0.71      0.70     38029
# weighted avg       0.74      0.71      0.70     38029
#
#
# Fold 5 - Accuracy: 0.7061, F1 Score: 0.7009
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89      7634
#            1       0.61      0.35      0.44      7524
#            2       0.57      0.87      0.69      7613
#            3       0.63      0.82      0.71      7672
#            4       0.88      0.69      0.77      7586
#
#     accuracy                           0.71     38029
#    macro avg       0.74      0.71      0.70     38029
# weighted avg       0.74      0.71      0.70     38029
#
#
#
# CategoricalNB - Mean Accuracy: 0.7055 (± 0.0024), Mean F1 Score: 0.7003 (± 0.0021)
#
# Evaluating ComplementNB...
# Fold 1 - Accuracy: 0.3859, F1 Score: 0.3354
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       0.54      0.31      0.39      7583
#            1       0.33      0.03      0.05      7703
#            2       0.34      0.68      0.45      7362
#            3       0.37      0.70      0.48      7626
#            4       0.49      0.22      0.31      7755
#
#     accuracy                           0.39     38029
#    macro avg       0.41      0.39      0.34     38029
# weighted avg       0.41      0.39      0.34     38029
#
#
# Fold 2 - Accuracy: 0.3882, F1 Score: 0.3489
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       0.56      0.28      0.37      7650
#            1       0.32      0.08      0.12      7541
#            2       0.35      0.64      0.46      7678
#            3       0.36      0.71      0.48      7631
#            4       0.50      0.23      0.31      7529
#
#     accuracy                           0.39     38029
#    macro avg       0.42      0.39      0.35     38029
# weighted avg       0.42      0.39      0.35     38029
#
#
# Fold 3 - Accuracy: 0.3974, F1 Score: 0.3580
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       0.57      0.30      0.39      7683
#            1       0.29      0.07      0.11      7585
#            2       0.36      0.66      0.47      7714
#            3       0.37      0.71      0.49      7544
#            4       0.52      0.25      0.33      7503
#
#     accuracy                           0.40     38029
#    macro avg       0.42      0.40      0.36     38029
# weighted avg       0.42      0.40      0.36     38029
#
#
# Fold 4 - Accuracy: 0.3923, F1 Score: 0.3486
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       0.54      0.28      0.37      7479
#            1       0.34      0.06      0.10      7676
#            2       0.35      0.66      0.46      7662
#            3       0.37      0.73      0.49      7556
#            4       0.51      0.24      0.32      7656
#
#     accuracy                           0.39     38029
#    macro avg       0.42      0.39      0.35     38029
# weighted avg       0.42      0.39      0.35     38029
#
#
# Fold 5 - Accuracy: 0.3950, F1 Score: 0.3571
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       0.54      0.27      0.36      7634
#            1       0.33      0.08      0.13      7524
#            2       0.36      0.65      0.46      7613
#            3       0.37      0.72      0.49      7672
#            4       0.53      0.25      0.34      7586
#
#     accuracy                           0.39     38029
#    macro avg       0.43      0.39      0.36     38029
# weighted avg       0.43      0.39      0.36     38029
#
#
#
# ComplementNB - Mean Accuracy: 0.3918 (± 0.0042), Mean F1 Score: 0.3496 (± 0.0081)
#
# Evaluating GaussianNB...
# Fold 1 - Accuracy: 0.8816, F1 Score: 0.8814
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      7583
#            1       0.80      0.79      0.79      7703
#            2       0.91      0.94      0.93      7362
#            3       0.79      0.79      0.79      7626
#            4       0.90      0.92      0.91      7755
#
#     accuracy                           0.88     38029
#    macro avg       0.88      0.88      0.88     38029
# weighted avg       0.88      0.88      0.88     38029
#
#
# Fold 2 - Accuracy: 0.8817, F1 Score: 0.8814
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99      7650
#            1       0.80      0.79      0.80      7541
#            2       0.92      0.94      0.93      7678
#            3       0.81      0.78      0.79      7631
#            4       0.88      0.92      0.90      7529
#
#     accuracy                           0.88     38029
#    macro avg       0.88      0.88      0.88     38029
# weighted avg       0.88      0.88      0.88     38029
#
#
# Fold 3 - Accuracy: 0.8831, F1 Score: 0.8829
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      7683
#            1       0.79      0.79      0.79      7585
#            2       0.93      0.95      0.94      7714
#            3       0.80      0.78      0.79      7544
#            4       0.90      0.92      0.91      7503
#
#     accuracy                           0.88     38029
#    macro avg       0.88      0.88      0.88     38029
# weighted avg       0.88      0.88      0.88     38029
#
#
# Fold 4 - Accuracy: 0.8860, F1 Score: 0.8859
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      7479
#            1       0.81      0.79      0.80      7676
#            2       0.92      0.94      0.93      7662
#            3       0.80      0.80      0.80      7556
#            4       0.91      0.92      0.91      7656
#
#     accuracy                           0.89     38029
#    macro avg       0.89      0.89      0.89     38029
# weighted avg       0.89      0.89      0.89     38029
#
#
# Fold 5 - Accuracy: 0.8822, F1 Score: 0.8820
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      7634
#            1       0.79      0.79      0.79      7524
#            2       0.92      0.94      0.93      7613
#            3       0.80      0.78      0.79      7672
#            4       0.90      0.91      0.91      7586
#
#     accuracy                           0.88     38029
#    macro avg       0.88      0.88      0.88     38029
# weighted avg       0.88      0.88      0.88     38029
#
#
#
# GaussianNB - Mean Accuracy: 0.8829 (± 0.0016), Mean F1 Score: 0.8827 (± 0.0017)
#
# Evaluating MultinomialNB...
# Fold 1 - Accuracy: 0.4284, F1 Score: 0.4141
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#            0       0.53      0.38      0.45      7583
#            1       0.39      0.17      0.24      7703
#            2       0.37      0.58      0.45      7362
#            3       0.45      0.60      0.51      7626
#            4       0.43      0.42      0.42      7755
#
#     accuracy                           0.43     38029
#    macro avg       0.43      0.43      0.41     38029
# weighted avg       0.43      0.43      0.41     38029
#
#
# Fold 2 - Accuracy: 0.4243, F1 Score: 0.4136
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#            0       0.56      0.35      0.43      7650
#            1       0.31      0.19      0.24      7541
#            2       0.37      0.53      0.44      7678
#            3       0.44      0.62      0.52      7631
#            4       0.45      0.43      0.44      7529
#
#     accuracy                           0.42     38029
#    macro avg       0.43      0.42      0.41     38029
# weighted avg       0.43      0.42      0.41     38029
#
#
# Fold 3 - Accuracy: 0.4290, F1 Score: 0.4186
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#            0       0.56      0.37      0.45      7683
#            1       0.31      0.20      0.24      7585
#            2       0.39      0.54      0.45      7714
#            3       0.45      0.61      0.52      7544
#            4       0.44      0.43      0.43      7503
#
#     accuracy                           0.43     38029
#    macro avg       0.43      0.43      0.42     38029
# weighted avg       0.43      0.43      0.42     38029
#
#
# Fold 4 - Accuracy: 0.4291, F1 Score: 0.4159
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#            0       0.54      0.36      0.43      7479
#            1       0.34      0.18      0.24      7676
#            2       0.38      0.54      0.44      7662
#            3       0.45      0.63      0.52      7556
#            4       0.46      0.43      0.44      7656
#
#     accuracy                           0.43     38029
#    macro avg       0.43      0.43      0.42     38029
# weighted avg       0.43      0.43      0.42     38029
#
#
# Fold 5 - Accuracy: 0.4271, F1 Score: 0.4163
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#            0       0.55      0.35      0.43      7634
#            1       0.32      0.20      0.24      7524
#            2       0.37      0.53      0.44      7613
#            3       0.45      0.62      0.52      7672
#            4       0.46      0.43      0.45      7586
#
#     accuracy                           0.43     38029
#    macro avg       0.43      0.43      0.42     38029
# weighted avg       0.43      0.43      0.42     38029
#
#
#
# MultinomialNB - Mean Accuracy: 0.4276 (± 0.0018), Mean F1 Score: 0.4157 (± 0.0018)
