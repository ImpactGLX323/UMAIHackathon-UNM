# %%
# Import libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# Load the processed dataset
df = pd.read_csv('../data/preprocessed/with_diabetes_status/dataset_with_diabetes_status.csv')

# %%
# Data inspection: view first 10 rows and shape
print("First ten rows of the dataset:")
display(df.head(10))

print("\nDataset dimensions:")
print(f"Number of rows: {df.shape[0]}, Number of columns: {df.shape[1]}")
# Out:
# First ten rows of the dataset:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
# 5  Female  20.0             0              0           never  27.32
# 6  Female  44.0             0              0           never  19.31
# 7  Female  79.0             0              0         No Info  23.86
# 8    Male  42.0             0              0           never  33.64
# 9  Female  32.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level  diabetes                 diabetes_status
# 0          6.6                  140         0  stress induced type 2 diabetic
# 1          6.6                   80         0  stress induced type 2 diabetic
# 2          5.7                  158         0      stress induced prediabetic
# 3          5.0                  155         0                    non diabetic
# 4          4.8                  155         0                    non diabetic
# 5          6.6                   85         0  stress induced type 2 diabetic
# 6          6.5                  200         1                        diabetic
# 7          5.7                   85         0      stress induced prediabetic
# 8          4.8                  145         0                    non diabetic
# 9          5.0                  100         0                    non diabetic
# Dataset dimensions:
# Number of rows: 100000, Number of columns: 10

# %%
# Data inspection: data information
print("\nDataset information:")
df.info()
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
#  9   diabetes_status      100000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 7.6+ MB

# %%
# Data inspection: statistical summary
print("\nStatistical summary:")
display(df.describe())
# Out:
# Statistical summary:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# 50%         5.800000           140.000000       0.000000
# 75%         6.200000           159.000000       0.000000
# max         9.000000           300.000000       1.000000

# %%
# Data inspection: unique values and counts
for column in df.columns:
    print(f"Unique values in '{column}':")
    print(df[column].unique())
    print(f"\nUnique value counts in '{column}':")
    print(df[column].value_counts())
    print("\n")
# Out:
# Unique values in 'gender':
# ['Female' 'Male' 'Other']
#
# Unique value counts in 'gender':
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64
#
#
# Unique values in 'age':
# [80.   54.   28.   36.   76.   20.   44.   79.   42.   32.   53.   78.
#  67.   15.   37.   40.    5.   69.   72.    4.   30.   45.   43.   50.
#  41.   26.   34.   73.   77.   66.   29.   60.   38.    3.   57.   74.
#  19.   46.   21.   59.   27.   13.   56.    2.    7.   11.    6.   55.
#   9.   62.   47.   12.   68.   75.   22.   58.   18.   24.   17.   25.
#   0.08 33.   16.   61.   31.    8.   49.   39.   65.   14.   70.    0.56
#  48.   51.   71.    0.88 64.   63.   52.    0.16 10.   35.   23.    0.64
#   1.16  1.64  0.72  1.88  1.32  0.8   1.24  1.    1.8   0.48  1.56  1.08
#   0.24  1.4   0.4   0.32  1.72  1.48]
#
# Unique value counts in 'age':
# age
# 80.00    5621
# 51.00    1619
# 47.00    1574
# 48.00    1568
# 53.00    1542
#          ...
# 0.48       83
# 1.00       83
# 0.40       66
# 0.16       59
# 0.08       36
# Name: count, Length: 102, dtype: int64
#
#
# Unique values in 'hypertension':
# [0 1]
#
# Unique value counts in 'hypertension':
# hypertension
# 0    92515
# 1     7485
# Name: count, dtype: int64
#
#
# Unique values in 'heart_disease':
# [1 0]
#
# Unique value counts in 'heart_disease':
# heart_disease
# 0    96058
# 1     3942
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history':
# ['never' 'No Info' 'current' 'former' 'ever' 'not current']
#
# Unique value counts in 'smoking_history':
# smoking_history
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64
#
#
# Unique values in 'bmi':
# [25.19 27.32 23.45 ... 59.42 44.39 60.52]
#
# Unique value counts in 'bmi':
# bmi
# 27.32    25495
# 23.00      103
# 27.12      101
# 27.80      100
# 24.96      100
#          ...
# 58.23        1
# 48.18        1
# 55.57        1
# 57.07        1
# 60.52        1
# Name: count, Length: 4247, dtype: int64
#
#
# Unique values in 'HbA1c_level':
# [6.6 5.7 5.  4.8 6.5 6.1 6.  5.8 3.5 6.2 4.  4.5 9.  7.  8.8 8.2 7.5 6.8]
#
# Unique value counts in 'HbA1c_level':
# HbA1c_level
# 6.6    8540
# 5.7    8413
# 6.5    8362
# 5.8    8321
# 6.0    8295
# 6.2    8269
# 6.1    8048
# 3.5    7662
# 4.8    7597
# 4.5    7585
# 4.0    7542
# 5.0    7471
# 8.8     661
# 8.2     661
# 9.0     654
# 7.5     643
# 6.8     642
# 7.0     634
# Name: count, dtype: int64
#
#
# Unique values in 'blood_glucose_level':
# [140  80 158 155  85 200 145 100 130 160 126 159  90 260 220 300 280 240]
#
# Unique value counts in 'blood_glucose_level':
# blood_glucose_level
# 130    7794
# 159    7759
# 140    7732
# 160    7712
# 126    7702
# 145    7679
# 200    7600
# 155    7575
# 90     7112
# 80     7106
# 158    7026
# 100    7025
# 85     6901
# 280     729
# 300     674
# 240     636
# 260     635
# 220     603
# Name: count, dtype: int64
#
#
# Unique values in 'diabetes':
# [0 1]
#
# Unique value counts in 'diabetes':
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64
#
#
# Unique values in 'diabetes_status':
# ['stress induced type 2 diabetic' 'stress induced prediabetic'
#  'non diabetic' 'diabetic' 'prediabetic']
#
# Unique value counts in 'diabetes_status':
# diabetes_status
# stress induced prediabetic        38037
# non diabetic                      37857
# stress induced type 2 diabetic    15606
# diabetic                           5191
# prediabetic                        3309
# Name: count, dtype: int64

# %%
# Drop the diabetes and hba1c columns
df = df.drop(['diabetes', 'HbA1c_level'], axis=1)

# %%
# Drop records where gender is 'Other'
df = df[df['gender'] != 'Other']

# %%
# One-hot encode categorical features
df = pd.get_dummies(df, columns=['gender', 'smoking_history'], drop_first=False)

# %%
# Define the order of categories for diabetes_status
status_order = ['non diabetic', 'stress induced prediabetic', 'stress induced type 2 diabetic', 'prediabetic', 'diabetic']

# Create a mapping for the specified order
status_mapping = {status: i for i, status in enumerate(status_order)}

# Map 'diabetes_status' to the numeric encoding
df['diabetes_status'] = df['diabetes_status'].map(status_mapping)

# %%
# Move the encoded 'diabetes_status' to the right
cols = df.columns.tolist()
cols.append(cols.pop(cols.index('diabetes_status')))
df = df[cols]

# %%
# Data re inspection: view first 10 rows and shape
print("First ten rows of the dataset:")
display(df.head(10))

print("\nDataset dimensions:")
print(f"Number of rows: {df.shape[0]}, Number of columns: {df.shape[1]}")
# Out:
# First ten rows of the dataset:
#     age  hypertension  heart_disease    bmi  blood_glucose_level  \
# 0  80.0             0              1  25.19                  140
# 1  54.0             0              0  27.32                   80
# 2  28.0             0              0  27.32                  158
# 3  36.0             0              0  23.45                  155
# 4  76.0             1              1  20.14                  155
# 5  20.0             0              0  27.32                   85
# 6  44.0             0              0  19.31                  200
# 7  79.0             0              0  23.86                   85
# 8  42.0             0              0  33.64                  145
# 9  32.0             0              0  27.32                  100
#
#    gender_Female  gender_Male  smoking_history_No Info  \
# 0           True        False                    False
# 1           True        False                     True
# 2          False         True                    False
# 3           True        False                    False
# 4          False         True                    False
# 5           True        False                    False
# 6           True        False                    False
# 7           True        False                     True
# 8          False         True                    False
# 9           True        False                    False
#
#    smoking_history_current  smoking_history_ever  smoking_history_former  \
# 0                    False                 False                   False
# 1                    False                 False                   False
# 2                    False                 False                   False
# 3                     True                 False                   False
# 4                     True                 False                   False
# 5                    False                 False                   False
# 6                    False                 False                   False
# 7                    False                 False                   False
# 8                    False                 False                   False
# 9                    False                 False                   False
#
#    smoking_history_never  smoking_history_not current  diabetes_status
# 0                   True                        False                2
# 1                  False                        False                2
# 2                   True                        False                1
# 3                  False                        False                0
# 4                  False                        False                0
# 5                   True                        False                2
# 6                   True                        False                4
# 7                  False                        False                1
# 8                   True                        False                0
# 9                   True                        False                0
# Dataset dimensions:
# Number of rows: 99982, Number of columns: 14

# %%
# Data re inspection: data information
print("\nDataset information:")
df.info()
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99982 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          99982 non-null  float64
#  1   hypertension                 99982 non-null  int64
#  2   heart_disease                99982 non-null  int64
#  3   bmi                          99982 non-null  float64
#  4   blood_glucose_level          99982 non-null  int64
#  5   gender_Female                99982 non-null  bool
#  6   gender_Male                  99982 non-null  bool
#  7   smoking_history_No Info      99982 non-null  bool
#  8   smoking_history_current      99982 non-null  bool
#  9   smoking_history_ever         99982 non-null  bool
#  10  smoking_history_former       99982 non-null  bool
#  11  smoking_history_never        99982 non-null  bool
#  12  smoking_history_not current  99982 non-null  bool
#  13  diabetes_status              99982 non-null  int64
# dtypes: bool(8), float64(2), int64(4)
# memory usage: 6.1 MB

# %%
# Data re inspection: statistical summary
print("\nStatistical summary:")
display(df.describe())
# Out:
# Statistical summary:
#                 age  hypertension  heart_disease           bmi  \
# count  99982.000000  99982.000000   99982.000000  99982.000000
# mean      41.888076      0.074863       0.039427     27.320757
# std       22.517206      0.263172       0.194610      6.636853
# min        0.080000      0.000000       0.000000     10.010000
# 25%       24.000000      0.000000       0.000000     23.630000
# 50%       43.000000      0.000000       0.000000     27.320000
# 75%       60.000000      0.000000       0.000000     29.580000
# max       80.000000      1.000000       1.000000     95.690000
#
#        blood_glucose_level  diabetes_status
# count         99982.000000     99982.000000
# mean            138.057810         0.999440
# std              40.709469         1.065033
# min              80.000000         0.000000
# 25%             100.000000         0.000000
# 50%             140.000000         1.000000
# 75%             159.000000         1.000000
# max             300.000000         4.000000

# %%
# Data re inspection: unique values and counts
for column in df.columns:
    print(f"Unique values in '{column}':")
    print(df[column].unique())
    print(f"\nUnique value counts in '{column}':")
    print(df[column].value_counts())
    print("\n")
# Out:
# Unique values in 'age':
# [80.   54.   28.   36.   76.   20.   44.   79.   42.   32.   53.   78.
#  67.   15.   37.   40.    5.   69.   72.    4.   30.   45.   43.   50.
#  41.   26.   34.   73.   77.   66.   29.   60.   38.    3.   57.   74.
#  19.   46.   21.   59.   27.   13.   56.    2.    7.   11.    6.   55.
#   9.   62.   47.   12.   68.   75.   22.   58.   18.   24.   17.   25.
#   0.08 33.   16.   61.   31.    8.   49.   39.   65.   14.   70.    0.56
#  48.   51.   71.    0.88 64.   63.   52.    0.16 10.   35.   23.    0.64
#   1.16  1.64  0.72  1.88  1.32  0.8   1.24  1.    1.8   0.48  1.56  1.08
#   0.24  1.4   0.4   0.32  1.72  1.48]
#
# Unique value counts in 'age':
# age
# 80.00    5621
# 51.00    1619
# 47.00    1572
# 48.00    1568
# 49.00    1541
#          ...
# 0.48       83
# 1.00       83
# 0.40       66
# 0.16       59
# 0.08       36
# Name: count, Length: 102, dtype: int64
#
#
# Unique values in 'hypertension':
# [0 1]
#
# Unique value counts in 'hypertension':
# hypertension
# 0    92497
# 1     7485
# Name: count, dtype: int64
#
#
# Unique values in 'heart_disease':
# [1 0]
#
# Unique value counts in 'heart_disease':
# heart_disease
# 0    96040
# 1     3942
# Name: count, dtype: int64
#
#
# Unique values in 'bmi':
# [25.19 27.32 23.45 ... 59.42 44.39 60.52]
#
# Unique value counts in 'bmi':
# bmi
# 27.32    25488
# 23.00      103
# 27.12      101
# 27.80      100
# 24.96      100
#          ...
# 53.28        1
# 55.38        1
# 40.26        1
# 51.75        1
# 60.52        1
# Name: count, Length: 4247, dtype: int64
#
#
# Unique values in 'blood_glucose_level':
# [140  80 158 155  85 200 145 100 130 160 126 159  90 260 220 300 280 240]
#
# Unique value counts in 'blood_glucose_level':
# blood_glucose_level
# 130    7794
# 159    7756
# 140    7730
# 160    7708
# 126    7700
# 145    7679
# 200    7599
# 155    7575
# 90     7110
# 80     7105
# 100    7025
# 158    7024
# 85     6900
# 280     729
# 300     674
# 240     636
# 260     635
# 220     603
# Name: count, dtype: int64
#
#
# Unique values in 'gender_Female':
# [ True False]
#
# Unique value counts in 'gender_Female':
# gender_Female
# True     58552
# False    41430
# Name: count, dtype: int64
#
#
# Unique values in 'gender_Male':
# [False  True]
#
# Unique value counts in 'gender_Male':
# gender_Male
# False    58552
# True     41430
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_No Info':
# [False  True]
#
# Unique value counts in 'smoking_history_No Info':
# smoking_history_No Info
# False    64172
# True     35810
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_current':
# [False  True]
#
# Unique value counts in 'smoking_history_current':
# smoking_history_current
# False    90696
# True      9286
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_ever':
# [False  True]
#
# Unique value counts in 'smoking_history_ever':
# smoking_history_ever
# False    95979
# True      4003
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_former':
# [False  True]
#
# Unique value counts in 'smoking_history_former':
# smoking_history_former
# False    90630
# True      9352
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_never':
# [ True False]
#
# Unique value counts in 'smoking_history_never':
# smoking_history_never
# False    64890
# True     35092
# Name: count, dtype: int64
#
#
# Unique values in 'smoking_history_not current':
# [False  True]
#
# Unique value counts in 'smoking_history_not current':
# smoking_history_not current
# False    93543
# True      6439
# Name: count, dtype: int64
#
#
# Unique values in 'diabetes_status':
# [2 1 0 4 3]
#
# Unique value counts in 'diabetes_status':
# diabetes_status
# 1    38029
# 0    37850
# 2    15603
# 4     5191
# 3     3309
# Name: count, dtype: int64

# %%
# Save the modified dataset
df.to_csv('../data/preprocessed/encoded/encoded_dataset_with_label_target.csv', index=False)
